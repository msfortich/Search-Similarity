# %%
# pip install sentence-transformers

# %%
# pip install hdbscan

# %%
import tensorflow_hub as hub
import pandas as pd
import numpy as np
import warnings
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy.spatial import distance
from sklearn.metrics.pairwise import cosine_distances
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import hdbscan
from sklearn.metrics import silhouette_score
import scipy.cluster.hierarchy as shc
warnings.filterwarnings("ignore")
import datetime as dt
import os
import re
from tqdm import tqdm
# import inflect
# import pycld2 as cld2
import regex

# %% [markdown]
# The query below pulls the search terms from the trends final report. I'm filtering by category and date. I would suggest pulling the data by category because pulling everything gives a lot of search terms. You can also play with the date and see if a different date gives better results.

# %%
# %%bigquery df
# SELECT search_term, kids, ya, adult,fiction, nonfiction, religious,christian,unknown,lemmatized_search_term, pct_rank
# FROM hc-data-prod-analytics.ds_prod.ds_trends_final_report
# WHERE title_care=False
# AND nonfiction = False
# AND fiction = True
# AND language = 'english'
# AND start_date >= '2024-06-01';
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df.head()
# Out:
#                             search_term   kids     ya  adult  fiction  \
# 0                     the last one left  False  False   True     True
# 1                              a a dark  False  False   True     True
# 2                             a.a. dark  False  False   True     True
# 3               zombie apocalypse books  False  False   True     True
# 4  tortured poets department piano book  False  False   True     True
#
#    nonfiction  religious  christian  unknown         lemmatized_search_term  \
# 0       False      False      False    False                 last leave one
# 1       False      False      False    False                           dark
# 2       False      False      False    False                       a.a dark
# 3       False      False      False    False              apocalypse zombie
# 4       False      False      False    False  department piano poet torture
#
#    pct_rank
# 0  0.567624
# 1  0.652423
# 2  0.685457
# 3  0.709801
# 4  0.638179

# %%
from google.cloud import bigquery
client = bigquery.Client(location="US")
print("Client creating using default project: {}".format(client.project))
# Out:
# Client creating using default project: hc-data-prod-analytics

# %%
terms = list(df['search_term'].unique())
terms[:5]
# Out:
# ['the last one left',
#  'a a dark',
#  'a.a. dark',
#  'zombie apocalypse books',
#  'tortured poets department piano book']

# %%
len(terms)
# Out:
# 5245

# %%
def chunks(l, n):
    """Yield successive n-sized chunks from l."""
    for i in range(0, len(l), n):
        yield l[i:i + n]

# %% [markdown]
# This query is pretty slow. It pulls the products associated to the search terms we pulled from the previous query. It's slow because it cycles through chunks of 1000 search terms. You can try to increase the number of search terms, or even try with all of them at once. I cycle through them because when I tried the query crashed. It might not crash if you apply stricter filters to the previous query.

# %%
# %%time
products = []
for chunk in chunks(terms,3000):
    chunk = '("'+'","'.join(chunk)+'")'   
    q="""
    SELECT clickeditemname, searchterm 
    FROM `hc-data-prod-analytics.datascience.amazon_weekly_search_term_full`
    WHERE searchterm IN {}
    """.format(chunk)
    products.append(client.query(q,location="US").to_dataframe())
# Out:
# CPU times: user 711 ms, sys: 246 ms, total: 957 ms
# Wall time: 11 s

# %%
# products

# %%
products = pd.concat(products)
products.head()
# Out:
#                                      clickeditemname          searchterm
# 0  The Complete Isaac Asimov's Foundation Series ...  issac asimov books
# 1                                         Foundation  issac asimov books
# 2                    The Robot Series ( 4 Book Set )  issac asimov books
# 3                       My Hero Academia, Vol. 1 (1)       my hero manga
# 4                     My Hero Academia, Vol. 30 (30)       my hero manga

# %%
products = products.groupby(['searchterm'])['clickeditemname'].apply(list)
products = pd.DataFrame(products)

# %%
df = pd.merge(df, products, how='left',left_on='search_term',right_on=products.index)
df.head()
# Out:
#                             search_term   kids     ya  adult  fiction  \
# 0                     the last one left  False  False   True     True
# 1                              a a dark  False  False   True     True
# 2                             a.a. dark  False  False   True     True
# 3               zombie apocalypse books  False  False   True     True
# 4  tortured poets department piano book  False  False   True     True
#
#    nonfiction  religious  christian  unknown         lemmatized_search_term  \
# 0       False      False      False    False                 last leave one
# 1       False      False      False    False                           dark
# 2       False      False      False    False                       a.a dark
# 3       False      False      False    False              apocalypse zombie
# 4       False      False      False    False  department piano poet torture
#
#    pct_rank                                    clickeditemname
# 0  0.567624  [The Only One Left: A Novel, The Only One Left...
# 1  0.652423  [24690 (24690 series Book 1), 24690, 24690: 24...
# 2  0.685457  [24690 (24690 series Book 1), 24690, 24690: 24...
# 3  0.709801  [The Light We Lost : A Post-Apocalyptic Surviv...
# 4  0.638179  [Taylor Swift - The Tortured Poets Department:...

# %%
df.shape
# Out:
# (7215, 12)

# %%
# df.drop_duplicates(inplace=True)

# %%
df = df.reset_index().sort_values(['search_term'])
df.head()
# Out:
#       index                     search_term   kids     ya  adult  fiction  \
# 6162   6162                  #1 best seller  False  False   True     True
# 2953   2953                            0.00  False  False   True     True
# 3084   3084          0.00 free kindle books  False  False   True     True
# 2960   2960  0.00 free kindle books romance  False  False   True     True
# 6092   6092                            0.99  False  False   True     True
#
#       nonfiction  religious  christian  unknown lemmatized_search_term  \
# 6162       False      False      False    False          1 seller well
# 2953       False      False      False    False                   0.00
# 3084       False      False      False    False              0.00 free
# 2960       False      False      False    False      0.00 free romance
# 6092       False      False      False    False                   0.99
#
#       pct_rank                                    clickeditemname
# 6162  0.017437  [BAGSMART Toiletry Bag Travel Bag with Hanging...
# 2953  0.689108  [The American Sign Language Alphabet – A Proje...
# 3084  0.907845  [The House of Closed Doors, Find Free Kindle B...
# 2960  0.477479  [Overruled by Love: A Small Town Romance (Boys...
# 6092  0.514151  [The Complete Father Brown Mysteries ($.99 Mys...

# %%
df.isna().sum()
# Out:
# index                     0
# search_term               0
# kids                      0
# ya                        0
# adult                     0
# fiction                   0
# nonfiction                0
# religious                 0
# christian                 0
# unknown                   0
# lemmatized_search_term    0
# pct_rank                  0
# clickeditemname           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# index                     0
# search_term               0
# kids                      0
# ya                        0
# adult                     0
# fiction                   0
# nonfiction                0
# religious                 0
# christian                 0
# unknown                   0
# lemmatized_search_term    0
# pct_rank                  0
# clickeditemname           0
# dtype: int64

# %% [markdown]
# tried both the universal sentence encoder and SBERT for the embeddings.  not really sure if one is better than the other

# %%
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# Generate embeddings for unique search terms
embeddings = model.encode(df['search_term'].unique().tolist())
embed_df = pd.DataFrame(embeddings, index=df['search_term'].unique())

# %%
# embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")
# embeddings = embed(newdf['search_term'].unique().tolist())
# len(embeddings), type(embeddings), print(embeddings.shape)

# %%
# embed_df = pd.DataFrame(embeddings.numpy())
# embed_df.index = newdf['search_term'].unique()

# %%
embed_df.shape
# Out:
# (5245, 384)

# %% [markdown]
# transforming the clicked items into a binary matrix

# %%
from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer(sparse_output=True)
mlb_array = mlb.fit_transform(df['clickeditemname'])

# %%
mlb_array = pd.DataFrame.sparse.from_spmatrix(mlb_array)
mlb_array['search_term'] = df['search_term'].values
mlb_array.drop_duplicates(subset=['search_term'],inplace=True)
mlb_array.index = mlb_array['search_term'].values
mlb_array.drop('search_term',axis=1,inplace=True)
print(mlb_array.shape)
# Out:
# (5245, 84285)

# %%
mlb_array.shape, embed_df.shape
# Out:
# ((5245, 84285), (5245, 384))

# %% [markdown]
# merging search term embeddings and clicked items

# %%
sim_df = embed_df.merge(mlb_array, left_on=embed_df.index, right_on=mlb_array.index)
sim_df.index = sim_df.iloc[:,0].values
sim_df.drop(['key_0'], axis=1,inplace=True)

# %%
# %%time
# sim = cosine_distances(sim_df)
# len(sim[0])

# %%
# semantic_sim = cosine_similarity(embed_df)
# clickeditems_sim = cosine_similarity(mlb_array)
# combined_sim = (semantic_sim * .8 + clickeditems_sim *.3)
# combined_sim_df = pd.Dataframe(combined_sim, index = embed_df.index, columns = embed_df.index)

# %%
# %%time
sim2 = cosine_similarity(sim_df)
# Out:
# CPU times: user 2min 34s, sys: 26.9 s, total: 3min 1s
# Wall time: 12.3 s

# %%
#converting matrix to a dataframe

sims_df = pd.DataFrame(sim2, index=embed_df.index, columns=embed_df.index)
sims_df.index.name = None
new_sims_df = sims_df.reset_index()
new_sims_df = new_sims_df.rename(columns={'index': 'Search Term'})
new_sims_df.head

melt = new_sims_df.melt(id_vars=["Search Term"], var_name="Compared Term", value_name="Similarity Score")

# %% [markdown]
# looking at the cosine similarity by grouping by search term and seeing what the top hits are
#
# setting the threshold based on similarity score didn't give the best results, since it doesn't account for the variability of scores for different search terms
# so tried to do it based on percentiles, and been testing different ones out

# %%
# threshold = .20
# melting = new_sims_df.melt(id_vars=["Search Term"], var_name="Compared Term", value_name="Similarity Score")
# peripheral = melting[melting["Similarity Score"] >= threshold]
# grouped_peripheral = peripheral.groupby("Search Term")

# setting a threshold based on quantiles/percentiles
def dynamic_threshold(df, quantile=0.99):
    thresholds = df.groupby('Search Term')['Similarity Score'].quantile(quantile)
    return thresholds

thresholds = dynamic_threshold(melt, quantile=0.99) # testing different percentiles
filtered_scores = melt.join(thresholds, on='Search Term', rsuffix='_threshold')
filtered_scores = filtered_scores[filtered_scores['Similarity Score'] >= filtered_scores['Similarity Score_threshold']].drop('Similarity Score_threshold', axis=1)


grouped_terms = filtered_scores.groupby("Search Term")

keyword = "enemies to lovers romance"  # testing different search terms

if keyword in grouped_terms.groups:
    compared_df = grouped_terms.get_group(keyword).reset_index(drop=True)
    # Sort by similarity score in descending order
    compared_df = compared_df.sort_values(by="Similarity Score", ascending=False)
else:
    compared_df = pd.DataFrame(columns=["Search Term", "Compared Term", "Similarity Score"])
    print(f"No peripheral words found for {keyword}")

compared_df.head(20)
# Out:
#                   Search Term                           Compared Term  \
# 15  enemies to lovers romance               enemies to lovers romance
# 16  enemies to lovers romance         enemies to lovers romance books
# 18  enemies to lovers romance           enemy to lovers romance books
# 17  enemies to lovers romance       enemies to lovers romance fantasy
# 27  enemies to lovers romance            mm enemies to lovers romance
# 13  enemies to lovers romance          enemies to lovers dark romance
# 51  enemies to lovers romance            why choose enemies to lovers
# 12  enemies to lovers romance           enemies to lovers books spicy
# 4   enemies to lovers romance                 angsty romance betrayal
# 14  enemies to lovers romance            enemies to lovers free books
# 29  enemies to lovers romance  mm romance novel best friends to lover
# 1   enemies to lovers romance                     abused mate romance
# 21  enemies to lovers romance             fated mates shifter romance
# 22  enemies to lovers romance                          flirting enemy
# 35  enemies to lovers romance                      protective romance
# 26  enemies to lovers romance             marriage in trouble romance
# 49  enemies to lovers romance                    vampire mate romance
# 48  enemies to lovers romance                 vampire fantasy romance
# 46  enemies to lovers romance         strong female character romance
# 41  enemies to lovers romance                      romantic thrillers
#
#     Similarity Score
# 15          1.000000
# 16          0.489985
# 18          0.447245
# 17          0.432283
# 27          0.421334
# 13          0.394696
# 51          0.390998
# 12          0.352690
# 4           0.322899
# 14          0.321018
# 29          0.315242
# 1           0.313994
# 21          0.312079
# 22          0.306862
# 35          0.304722
# 26          0.304037
# 49          0.302066
# 48          0.299062
# 46          0.298994
# 41          0.296687

# %% [markdown]
# here i'm testing the threshold, by using the table below, left joining it with the cosine sim matrix, and grouping by trend.
# this way you can see the search terms that are already mapped in the trend, along with the unmapped search terms that fall into the trend based on the threshold set

# %%
# %%bigquery df_trends
# SELECT * FROM `hc-data-prod-analytics.oss.bi_dashboard_trends_living_searchterms`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df_trends.head()
# Out:
#              searchterm    trend
# 0       tiktok cookbook  Booktok
# 1              book tok  Booktok
# 2    booktok books 2024  Booktok
# 3  tiktok cookbook 2023  Booktok
# 4       booktok journal  Booktok

# %%
def dynamic_threshold(df, quantile=0.99):
    thresholds = df.groupby('Search Term')['Similarity Score'].quantile(quantile)
    return thresholds

thresholds = dynamic_threshold(melt, quantile=0.99)

filtered = melt.join(thresholds, on='Search Term', rsuffix='_threshold')
filtered = filtered[filtered['Similarity Score'] >= filtered['Similarity Score_threshold']].drop('Similarity Score_threshold', axis=1)
# merging table with the cosine sim matrix
filtered_with_trends = filtered.merge(df_trends, left_on='Search Term', right_on='searchterm', how='left')
filtered_with_trends['trend'] = filtered_with_trends['trend'].fillna('Unmapped') # setting 'Unmapped' in the trend column for all the search terms not already in the trends table 
filtered_with_trends.head() # Search Term is the cosine sim matrix and searchterm is from the trends table
# Out:
#                    Search Term   Compared Term  Similarity Score searchterm  \
# 0               #1 best seller  #1 best seller          1.000000        NaN
# 1             best sellers nyt  #1 best seller          0.466641        NaN
# 2                 booker prize  #1 best seller          0.242559        NaN
# 3       chick lit best sellers  #1 best seller          0.426865        NaN
# 4  kindle top 100 best sellers  #1 best seller          0.464779        NaN
#
#       trend
# 0  Unmapped
# 1  Unmapped
# 2  Unmapped
# 3  Unmapped
# 4  Unmapped

# %%
#indicates whether the search term was originally unmapped
filtered_with_trends['Unmapped/Mapped'] = filtered_with_trends['trend'].apply(lambda x: 'Unmapped' if x == 'Unmapped' else 'Mapped')
compared_trends = df_trends.rename(columns={'searchterm': 'Compared Term', 'trend': 'Compared Trend'})
filtered_with_trends = filtered_with_trends.merge(compared_trends, on='Compared Term', how='left', suffixes=('', '_compared'))
filtered_with_trends['Compared Trend'] = filtered_with_trends['Compared Trend'].fillna('Unmapped')

#indicates whether the compared term was originally unmapped
filtered_with_trends['Compared Term Unmapped/Mapped'] = filtered_with_trends['Compared Trend'].apply(lambda x: 'Unmapped' if x == 'Unmapped' else 'Mapped')
filtered_with_trends['Final Trend'] = filtered_with_trends.apply(lambda x: x['trend'] if x['trend'] != 'Unmapped' else x['Compared Trend'], axis=1)
grouped_peripheral = filtered_with_trends.groupby("Final Trend")

# %%
results = []
for trend, group in grouped_peripheral:
    group = group.reset_index(drop=True)
    group = group.sort_values(by="Similarity Score", ascending=False)
    results.append(group)
final_df = pd.concat(results).reset_index(drop=True)


trend = "Enemies to Lovers Romance"  # testing different trends

if trend in final_df['Final Trend'].values:
    peripheral_df = final_df[final_df['Final Trend'] == trend]
else:
    peripheral_df = pd.DataFrame(columns=["Search Term", "Compared Term", "Similarity Score", "Final Trend", "Unmapped_Indicator", "Unmapped_Compared_Indicator"])
    print(f"No peripheral words found for {example_trend}")

print(peripheral_df.shape)
peripheral_df.head()
# Out:
# (900, 9)
#                             Search Term                    Compared Term  \
# 100001        enemies to lovers romance        enemies to lovers romance
# 100002        enemies to lovers romance        enemies to lovers romance
# 100003        enemies to lovers romance        enemies to lovers romance
# 100004        enemies to lovers romance        enemies to lovers romance
# 100005  enemies to lovers romance books  enemies to lovers romance books
#
#         Similarity Score                       searchterm  \
# 100001               1.0        enemies to lovers romance
# 100002               1.0        enemies to lovers romance
# 100003               1.0        enemies to lovers romance
# 100004               1.0        enemies to lovers romance
# 100005               1.0  enemies to lovers romance books
#
#                             trend Unmapped/Mapped             Compared Trend  \
# 100001  Enemies to Lovers Romance          Mapped               Romcom Books
# 100002  Enemies to Lovers Romance          Mapped            Romantic Comedy
# 100003  Enemies to Lovers Romance          Mapped                All Romance
# 100004  Enemies to Lovers Romance          Mapped  Enemies to Lovers Romance
# 100005  Enemies to Lovers Romance          Mapped               Romcom Books
#
#        Compared Term Unmapped/Mapped                Final Trend
# 100001                        Mapped  Enemies to Lovers Romance
# 100002                        Mapped  Enemies to Lovers Romance
# 100003                        Mapped  Enemies to Lovers Romance
# 100004                        Mapped  Enemies to Lovers Romance
# 100005                        Mapped  Enemies to Lovers Romance

# %%
peripheral_df['Similarity Score'] = peripheral_df['Similarity Score'].round(4)
df2 = peripheral_df[peripheral_df['Similarity Score'] < 1] 
df2.head()
# Out:
#                               Search Term                  Compared Term  \
# 100026  enemies to lovers romance fantasy   mm enemies to lovers romance
# 100027  enemies to lovers romance fantasy   mm enemies to lovers romance
# 100028    enemies to lovers romance books  enemy to lovers romance books
# 100029    enemies to lovers romance books  enemy to lovers romance books
# 100030  enemies to lovers romance fantasy  enemy to lovers romance books
#
#         Similarity Score                         searchterm  \
# 100026            0.7060  enemies to lovers romance fantasy
# 100027            0.7060  enemies to lovers romance fantasy
# 100028            0.6504    enemies to lovers romance books
# 100029            0.6504    enemies to lovers romance books
# 100030            0.6407  enemies to lovers romance fantasy
#
#                             trend Unmapped/Mapped Compared Trend  \
# 100026  Enemies to Lovers Romance          Mapped   Romcom Books
# 100027  Enemies to Lovers Romance          Mapped    All Romance
# 100028  Enemies to Lovers Romance          Mapped   Romcom Books
# 100029  Enemies to Lovers Romance          Mapped    All Romance
# 100030  Enemies to Lovers Romance          Mapped   Romcom Books
#
#        Compared Term Unmapped/Mapped                Final Trend
# 100026                        Mapped  Enemies to Lovers Romance
# 100027                        Mapped  Enemies to Lovers Romance
# 100028                        Mapped  Enemies to Lovers Romance
# 100029                        Mapped  Enemies to Lovers Romance
# 100030                        Mapped  Enemies to Lovers Romance

# %%
# peripheral_df.to_csv('98th Percentile Sports Romance.csv')

# %% [markdown]
# looking at the compared terms not mapped to the trend we're looking at

# %%
mapped_to_trend = peripheral_df[peripheral_df['Compared Trend'] == "Enemies to Lovers Romance"]['Compared Term'].unique()

# %%
#filter out terms not in the trend
df3 = df2[~df2['Compared Term'].isin(mapped_to_trend) & (df2['Compared Trend'] != 'Unmapped')]
print(df3.shape)
print(df3['Compared Term'].nunique())
# df3.to_csv('98th Percentile Sports Romance - Compared Terms Not Mapped to Original Trend.csv')
# Out:
# (633, 9)
# 128

# %%
df3.head()
# Out:
#                               Search Term                  Compared Term  \
# 100026  enemies to lovers romance fantasy   mm enemies to lovers romance
# 100027  enemies to lovers romance fantasy   mm enemies to lovers romance
# 100028    enemies to lovers romance books  enemy to lovers romance books
# 100029    enemies to lovers romance books  enemy to lovers romance books
# 100030  enemies to lovers romance fantasy  enemy to lovers romance books
#
#         Similarity Score                         searchterm  \
# 100026            0.7060  enemies to lovers romance fantasy
# 100027            0.7060  enemies to lovers romance fantasy
# 100028            0.6504    enemies to lovers romance books
# 100029            0.6504    enemies to lovers romance books
# 100030            0.6407  enemies to lovers romance fantasy
#
#                             trend Unmapped/Mapped Compared Trend  \
# 100026  Enemies to Lovers Romance          Mapped   Romcom Books
# 100027  Enemies to Lovers Romance          Mapped    All Romance
# 100028  Enemies to Lovers Romance          Mapped   Romcom Books
# 100029  Enemies to Lovers Romance          Mapped    All Romance
# 100030  Enemies to Lovers Romance          Mapped   Romcom Books
#
#        Compared Term Unmapped/Mapped                Final Trend
# 100026                        Mapped  Enemies to Lovers Romance
# 100027                        Mapped  Enemies to Lovers Romance
# 100028                        Mapped  Enemies to Lovers Romance
# 100029                        Mapped  Enemies to Lovers Romance
# 100030                        Mapped  Enemies to Lovers Romance

# %% [markdown]
# looking at the already mapped search terms compared to the unmapped search terms that fall within the threshold

# %%
df4 = peripheral_df[(peripheral_df['Compared Term Unmapped/Mapped'] == 'Unmapped')]
# df4.to_csv('98th Percentile Sports Romance - Compared Terms Not Mapped to Any Trend.csv')
df4
# Out:
#                               Search Term  \
# 100041  enemies to lovers romance fantasy
# 100050       enemies to lovers free books
# 100086       enemies to lovers free books
# 100113       enemies to lovers free books
# 100115  enemies to lovers romance fantasy
# 100138       enemies to lovers free books
# 100147       enemies to lovers free books
# 100150       enemies to lovers free books
# 100152       enemies to lovers free books
# 100161       enemies to lovers free books
# 100248       enemies to lovers free books
# 100249       enemies to lovers free books
# 100251       enemies to lovers free books
# 100252  enemies to lovers romance fantasy
# 100268       enemies to lovers free books
# 100269       enemies to lovers free books
# 100293  enemies to lovers romance fantasy
# 100295       enemies to lovers free books
# 100300       enemies to lovers free books
# 100302  enemies to lovers romance fantasy
# 100319       enemies to lovers free books
# 100328  enemies to lovers romance fantasy
# 100349  enemies to lovers romance fantasy
# 100371      enemies to lovers books spicy
# 100377      enemies to lovers books spicy
# 100384     enemies to lovers dark romance
# 100386      enemies to lovers books spicy
# 100401    enemies to lovers romance books
# 100515    enemies to lovers romance books
# 100523    enemies to lovers romance books
# 100524     enemies to lovers dark romance
# 100582      enemies to lovers books spicy
# 100607      enemies to lovers books spicy
# 100608     enemies to lovers dark romance
# 100611     enemies to lovers dark romance
# 100615    enemies to lovers romance books
# 100642          enemies to lovers romance
# 100704     enemies to lovers dark romance
# 100765          enemies to lovers romance
# 100784          enemies to lovers romance
# 100816          enemies to lovers romance
#
#                                             Compared Term  Similarity Score  \
# 100041                       why choose enemies to lovers            0.5744
# 100050                            friends to lovers books            0.5640
# 100086                     little library of banned books            0.5491
# 100113                                free novels to read            0.5368
# 100115                                 romantic thrillers            0.5340
# 100138                                  free books to buy            0.5219
# 100147                                    full free books            0.5189
# 100150                lulu dean's library of banned books            0.5164
# 100152                                 buy for free books            0.5161
# 100161                                  folk horror books            0.5152
# 100248                             thriller books on sale            0.4917
# 100249                            diary free kindle books            0.4914
# 100251                       why choose enemies to lovers            0.4912
# 100252       clean and wholesome romantic suspense ebooks            0.4906
# 100268                                 the strangers book            0.4862
# 100269                       free christian mystery books            0.4859
# 100293                                  free sexy romance            0.4827
# 100295                                   disturbing books            0.4826
# 100300                                   books used cheap            0.4814
# 100302                                witches secret love            0.4806
# 100319  free kindle books mystery and suspense detecti...            0.4785
# 100328                       best romantic suspense books            0.4772
# 100349                       lesbian mystery and thriller            0.4697
# 100371                      spicy books for women booktok            0.4622
# 100377                            friends to lovers books            0.4581
# 100384                       why choose enemies to lovers            0.4560
# 100386                                         spicy book            0.4540
# 100401                            friends to lovers books            0.4491
# 100515                       best romantic suspense books            0.4112
# 100523               sexy romance books best sellers 2024            0.4096
# 100524                                 romantic thrillers            0.4092
# 100582                                  folk horror books            0.4018
# 100607                             thriller books on sale            0.3983
# 100608                                witches secret love            0.3978
# 100611                                     flirting enemy            0.3978
# 100615       clean and wholesome romantic suspense ebooks            0.3975
# 100642                       why choose enemies to lovers            0.3910
# 100704                       best romantic suspense books            0.3702
# 100765                                     flirting enemy            0.3069
# 100784                                 romantic thrillers            0.2967
# 100816                                witches secret love            0.2827
#
#                                searchterm                      trend  \
# 100041  enemies to lovers romance fantasy  Enemies to Lovers Romance
# 100050       enemies to lovers free books  Enemies to Lovers Romance
# 100086       enemies to lovers free books  Enemies to Lovers Romance
# 100113       enemies to lovers free books  Enemies to Lovers Romance
# 100115  enemies to lovers romance fantasy  Enemies to Lovers Romance
# 100138       enemies to lovers free books  Enemies to Lovers Romance
# 100147       enemies to lovers free books  Enemies to Lovers Romance
# 100150       enemies to lovers free books  Enemies to Lovers Romance
# 100152       enemies to lovers free books  Enemies to Lovers Romance
# 100161       enemies to lovers free books  Enemies to Lovers Romance
# 100248       enemies to lovers free books  Enemies to Lovers Romance
# 100249       enemies to lovers free books  Enemies to Lovers Romance
# 100251       enemies to lovers free books  Enemies to Lovers Romance
# 100252  enemies to lovers romance fantasy  Enemies to Lovers Romance
# 100268       enemies to lovers free books  Enemies to Lovers Romance
# 100269       enemies to lovers free books  Enemies to Lovers Romance
# 100293  enemies to lovers romance fantasy  Enemies to Lovers Romance
# 100295       enemies to lovers free books  Enemies to Lovers Romance
# 100300       enemies to lovers free books  Enemies to Lovers Romance
# 100302  enemies to lovers romance fantasy  Enemies to Lovers Romance
# 100319       enemies to lovers free books  Enemies to Lovers Romance
# 100328  enemies to lovers romance fantasy  Enemies to Lovers Romance
# 100349  enemies to lovers romance fantasy  Enemies to Lovers Romance
# 100371      enemies to lovers books spicy  Enemies to Lovers Romance
# 100377      enemies to lovers books spicy  Enemies to Lovers Romance
# 100384     enemies to lovers dark romance  Enemies to Lovers Romance
# 100386      enemies to lovers books spicy  Enemies to Lovers Romance
# 100401    enemies to lovers romance books  Enemies to Lovers Romance
# 100515    enemies to lovers romance books  Enemies to Lovers Romance
# 100523    enemies to lovers romance books  Enemies to Lovers Romance
# 100524     enemies to lovers dark romance  Enemies to Lovers Romance
# 100582      enemies to lovers books spicy  Enemies to Lovers Romance
# 100607      enemies to lovers books spicy  Enemies to Lovers Romance
# 100608     enemies to lovers dark romance  Enemies to Lovers Romance
# 100611     enemies to lovers dark romance  Enemies to Lovers Romance
# 100615    enemies to lovers romance books  Enemies to Lovers Romance
# 100642          enemies to lovers romance  Enemies to Lovers Romance
# 100704     enemies to lovers dark romance  Enemies to Lovers Romance
# 100765          enemies to lovers romance  Enemies to Lovers Romance
# 100784          enemies to lovers romance  Enemies to Lovers Romance
# 100816          enemies to lovers romance  Enemies to Lovers Romance
#
#        Unmapped/Mapped Compared Trend Compared Term Unmapped/Mapped  \
# 100041          Mapped       Unmapped                      Unmapped
# 100050          Mapped       Unmapped                      Unmapped
# 100086          Mapped       Unmapped                      Unmapped
# 100113          Mapped       Unmapped                      Unmapped
# 100115          Mapped       Unmapped                      Unmapped
# 100138          Mapped       Unmapped                      Unmapped
# 100147          Mapped       Unmapped                      Unmapped
# 100150          Mapped       Unmapped                      Unmapped
# 100152          Mapped       Unmapped                      Unmapped
# 100161          Mapped       Unmapped                      Unmapped
# 100248          Mapped       Unmapped                      Unmapped
# 100249          Mapped       Unmapped                      Unmapped
# 100251          Mapped       Unmapped                      Unmapped
# 100252          Mapped       Unmapped                      Unmapped
# 100268          Mapped       Unmapped                      Unmapped
# 100269          Mapped       Unmapped                      Unmapped
# 100293          Mapped       Unmapped                      Unmapped
# 100295          Mapped       Unmapped                      Unmapped
# 100300          Mapped       Unmapped                      Unmapped
# 100302          Mapped       Unmapped                      Unmapped
# 100319          Mapped       Unmapped                      Unmapped
# 100328          Mapped       Unmapped                      Unmapped
# 100349          Mapped       Unmapped                      Unmapped
# 100371          Mapped       Unmapped                      Unmapped
# 100377          Mapped       Unmapped                      Unmapped
# 100384          Mapped       Unmapped                      Unmapped
# 100386          Mapped       Unmapped                      Unmapped
# 100401          Mapped       Unmapped                      Unmapped
# 100515          Mapped       Unmapped                      Unmapped
# 100523          Mapped       Unmapped                      Unmapped
# 100524          Mapped       Unmapped                      Unmapped
# 100582          Mapped       Unmapped                      Unmapped
# 100607          Mapped       Unmapped                      Unmapped
# 100608          Mapped       Unmapped                      Unmapped
# 100611          Mapped       Unmapped                      Unmapped
# 100615          Mapped       Unmapped                      Unmapped
# 100642          Mapped       Unmapped                      Unmapped
# 100704          Mapped       Unmapped                      Unmapped
# 100765          Mapped       Unmapped                      Unmapped
# 100784          Mapped       Unmapped                      Unmapped
# 100816          Mapped       Unmapped                      Unmapped
#
#                       Final Trend
# 100041  Enemies to Lovers Romance
# 100050  Enemies to Lovers Romance
# 100086  Enemies to Lovers Romance
# 100113  Enemies to Lovers Romance
# 100115  Enemies to Lovers Romance
# 100138  Enemies to Lovers Romance
# 100147  Enemies to Lovers Romance
# 100150  Enemies to Lovers Romance
# 100152  Enemies to Lovers Romance
# 100161  Enemies to Lovers Romance
# 100248  Enemies to Lovers Romance
# 100249  Enemies to Lovers Romance
# 100251  Enemies to Lovers Romance
# 100252  Enemies to Lovers Romance
# 100268  Enemies to Lovers Romance
# 100269  Enemies to Lovers Romance
# 100293  Enemies to Lovers Romance
# 100295  Enemies to Lovers Romance
# 100300  Enemies to Lovers Romance
# 100302  Enemies to Lovers Romance
# 100319  Enemies to Lovers Romance
# 100328  Enemies to Lovers Romance
# 100349  Enemies to Lovers Romance
# 100371  Enemies to Lovers Romance
# 100377  Enemies to Lovers Romance
# 100384  Enemies to Lovers Romance
# 100386  Enemies to Lovers Romance
# 100401  Enemies to Lovers Romance
# 100515  Enemies to Lovers Romance
# 100523  Enemies to Lovers Romance
# 100524  Enemies to Lovers Romance
# 100582  Enemies to Lovers Romance
# 100607  Enemies to Lovers Romance
# 100608  Enemies to Lovers Romance
# 100611  Enemies to Lovers Romance
# 100615  Enemies to Lovers Romance
# 100642  Enemies to Lovers Romance
# 100704  Enemies to Lovers Romance
# 100765  Enemies to Lovers Romance
# 100784  Enemies to Lovers Romance
# 100816  Enemies to Lovers Romance

# %%
df4['Search Term'].unique() #these are the search terms that are alredy mapped to the trend
# Out:
# array(['enemies to lovers romance fantasy',
#        'enemies to lovers free books', 'enemies to lovers books spicy',
#        'enemies to lovers dark romance',
#        'enemies to lovers romance books', 'enemies to lovers romance'],
#       dtype=object)

# %%
print(df4['Compared Term'].nunique())
df4['Compared Term'].unique() # unique unmapped terms
# Out:
# 26
# array(['why choose enemies to lovers', 'friends to lovers books',
#        'little library of banned books', 'free novels to read',
#        'romantic thrillers', 'free books to buy', 'full free books',
#        "lulu dean's library of banned books", 'buy for free books',
#        'folk horror books', 'thriller books on sale',
#        'diary free kindle books',
#        'clean and wholesome romantic suspense ebooks',
#        'the strangers book', 'free christian mystery books',
#        'free sexy romance', 'disturbing books', 'books used cheap',
#        'witches secret love',
#        'free kindle books mystery and suspense detective series',
#        'best romantic suspense books', 'lesbian mystery and thriller',
#        'spicy books for women booktok', 'spicy book',
#        'sexy romance books best sellers 2024', 'flirting enemy'],
#       dtype=object)

# %%
df_trends.trend.unique()
# Out:
# array(['Booktok', 'Fantasy', 'Box Sets', 'Cookbook', 'July 4th',
#        'Literary', 'Stoicism', 'Astrology', 'Book Club', 'Earth Day',
#        'Romantasy', 'AAPI Month', 'Cozy Books', 'Gift Books',
#        'Juneteenth', 'All Romance', 'Beach Books', 'Board Books',
#        'Craft Books', 'Deluxe Book', 'Pride Month', 'Winter Read',
#        'World War 2', 'Young Adult', 'Baby Romance', 'Banned Books',
#        'Bedtime Book', 'Black Friday', 'Budget Books', 'Cozy Fantasy',
#        'Cozy Mystery', 'Cute Animals', 'Dark Romance', 'Easter Books',
#        "Father's Day", 'Horror Books', 'Memorial Day', "Mother's Day",
#        'Nerd Romance', 'Poetry Month', 'Romcom Books', 'Stress Books',
#        'Veterans Day', 'Witchy Books', 'Alpha Romance', 'Amish Romance',
#        'Angst Romance', 'Anxiety Books', 'Bully Romance', 'Canning Books',
#        'Clean Romance', 'Cocktail Book', 'Crime Romance', 'Divorce Books',
#        'Drawing Books', 'Easy Cookbook', 'Graphic Novel', 'Grilling Book',
#        'Harem Romance', 'Keto Cookbook', 'Mafia Romance', 'Mystery Books',
#        'Reverse Harem', 'Royal Romance', 'Spicy Romance', 'Sticker Books',
#        'Urban Romance', 'Western Books', 'Witch Romance', 'World History',
#        'Adult Activity', 'Back To School', 'Dinosaur Books',
#        'LGBTQ+ Romance', 'Potty Training', 'Romance Series',
#        'School Romance', 'Single Romance', 'Social Justice',
#        'Sports Romance', 'Viking Romance', 'White Elephant',
#        'Zombie Romance', 'Age Gap Romance', 'Christian Bible',
#        'Christmas Books', 'Christmas Gifts', 'College Romance',
#        'Fantasy Romance', 'Gardening Books', 'Greek Mythology',
#        'Grumpy Sunshine', 'Halloween Books', 'Holiday Romance',
#        'Monster Romance', 'Mystery Romance', 'Parenting Books',
#        'Pregnancy Books', 'Regency Romance', 'Romantic Comedy',
#        'Science Fiction', 'Self Help Books', 'Shifter Romance',
#        'Spiritual Books', "Valentine's Day", 'Vampire Romance',
#        'Western Romance', 'American History', 'Graduation Books',
#        'Healthy Cookbook', 'Kindle Unlimited', 'Marriage Romance',
#        'Military Romance', 'Scottish Romance', 'Shy Girl Romance',
#        'Thriller Romance', 'Airfryer Cookbook', 'Christian Romance',
#        'Christmas Romance', 'Christmas in July', 'Instalove Romance',
#        'Mythology Romance', 'New Adult Romance', 'Polyamory Romance',
#        'Pregnancy Romance', 'Protector Romance', 'Rock Star Romance',
#        'Shadow Work Books', 'Workplace Romance', 'Cozy Coloring Book',
#        'Entrepreneur Books', 'Historical Romance', 'Meal Planner Books',
#        'Motivational Books', 'Omegaverse Romance', 'Paranormal Romance',
#        'Self Healing Books', 'Thanksgiving Books', 'Black History Month',
#        'Celebrity Book Club', 'Chrismas Gift Games',
#        'Inspirational Books', 'Interracial Romance',
#        'Manga/Anime Romance', 'Time Travel Romance',
#        'World War 2 Fiction', 'Adult Coloring Books',
#        'Art (Drawing & Paint)', 'Body Positive Romance',
#        'History and War Books', 'Jewish Heritage Month',
#        'Native American Books', 'Second Chance Romance',
#        "Women's History Month", 'Chinese Lunar New Year',
#        'Crystals and Astrology', 'Martin Luther King Day',
#        'Meditteranean Cookbook', 'Children Activity Books',
#        'Science Fiction Romance', 'African American Romance',
#        'Illustrated Edition Book', 'Non-Adult Coloring Books',
#        'Enemies to Lovers Romance', 'Fake Relationship Romance',
#        'Holocaust Remembrance Day', 'Teen & Young Adult Romance',
#        'National Parks, Hiking, Camping',
#        'Vegetarian, Vegan, Plant-Based Cookbook'], dtype=object)
